# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("D:\\Machine Learning\\Stud_part1.csv")
df.head()
# Out:
#    regnum  name  attendance  theorymarks city studyhours cgpa
# 0     100  ravi          80           85  blr          3    4
# 1     101  manu          50           60  chn          3    9
# 2     102  raja          32           50  hyd          8    7
# 3     103  manu          85           80  mum          3    6
# 4     104  arun          86           70  del          1    7

# %%
df1=pd.read_csv("D:\\Machine Learning\\Stud_part2.csv")
df1.head()
# Out:
#    regnum city studyhours cgpa
# 0     100  blr          3    4
# 1     101  chn          3    9
# 2     102  hyd          8    7
# 3     103  mum          3    6
# 4     104  del          1    7

# %%
stud = pd.merge(df, df1, how = 'inner', on = 'regnum')
print(stud)
# Out:
#     regnum      name  attendance  theorymarks  city_x studyhours_x cgpa_x  \
# 0      100      ravi          80           85     blr            3      4
# 1      101      manu          50           60     chn            3      9
# 2      102      raja          32           50     hyd            8      7
# 3      103      manu          85           80     mum            3      6
# 4      104      arun          86           70     del            1      7
# 5      105    mahesh          53           48   noida            4      8
# 6      106    rajesh          19           69    pune            7      4
# 7      107    mahesh          14           68     blr            4      8
# 8      108    rakesh          18           78   noida            3      6
# 9      109     manju          88           57  jaipur            4      8
# 10     110      raju          80           80     blr            4      5
# 11     111      guru          93           80     del            7      9
# ...

# %%
stud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   regnum        53 non-null     int64
#  1   name          53 non-null     object
#  2   attendance    53 non-null     int64
#  3   theorymarks   53 non-null     int64
#  4   city_x        53 non-null     object
#  5   studyhours_x  53 non-null     object
#  6   cgpa_x        53 non-null     object
#  7   city_y        53 non-null     object
#  8   studyhours_y  53 non-null     object
#  9   cgpa_y        53 non-null     object
# dtypes: int64(3), object(7)
# memory usage: 4.3+ KB

# %%
stud.replace("data", np.nan,inplace=True)
stud.replace("one", np.nan,inplace=True)
stud.replace("two", np.nan,inplace=True)

# %%
stud
# Out:
#     regnum      name  attendance  theorymarks  city_x studyhours_x cgpa_x  \
# 0      100      ravi          80           85     blr            3      4
# 1      101      manu          50           60     chn            3      9
# 2      102      raja          32           50     hyd            8      7
# 3      103      manu          85           80     mum            3      6
# 4      104      arun          86           70     del            1      7
# 5      105    mahesh          53           48   noida            4      8
# 6      106    rajesh          19           69    pune            7      4
# 7      107    mahesh          14           68     blr            4      8
# 8      108    rakesh          18           78   noida            3      6
# 9      109     manju          88           57  jaipur            4      8
# 10     110      raju          80           80     blr            4      5
# 11     111      guru          93           80     del            7      9
# ...

# %%
stud.fillna(0, inplace = True)
stud
# Out:
#     regnum      name  attendance  theorymarks  city_x  studyhours_x cgpa_x  \
# 0      100      ravi          80           85     blr           3.0      4
# 1      101      manu          50           60     chn           3.0      9
# 2      102      raja          32           50     hyd           8.0      7
# 3      103      manu          85           80     mum           3.0      6
# 4      104      arun          86           70     del           1.0      7
# 5      105    mahesh          53           48   noida           4.0      8
# 6      106    rajesh          19           69    pune           7.0      4
# 7      107    mahesh          14           68     blr           4.0      8
# 8      108    rakesh          18           78   noida           3.0      6
# 9      109     manju          88           57  jaipur           4.0      8
# 10     110      raju          80           80     blr           4.0      5
# ...

# %%
stud["studyhours_x"] = stud["studyhours_x"].astype(np.int64)
stud["studyhours_y"] = stud["studyhours_y"].astype(np.int64)
stud["cgpa_x"] = stud["cgpa_x"].astype(np.int64)
stud["cgpa_y"] = stud["cgpa_y"].astype(np.int64)
stud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   regnum        53 non-null     int64
#  1   name          53 non-null     object
#  2   attendance    53 non-null     int64
#  3   theorymarks   53 non-null     int64
#  4   city_x        53 non-null     object
#  5   studyhours_x  53 non-null     int64
#  6   cgpa_x        53 non-null     int64
#  7   city_y        53 non-null     object
#  8   studyhours_y  53 non-null     int64
#  9   cgpa_y        53 non-null     int64
# dtypes: int64(7), object(3)
# memory usage: 4.3+ KB

# %%
median_value = stud["studyhours_x"].median()
stud["studyhours_x"] = stud["studyhours_x"].replace(0, median_value)
median_value = stud["cgpa_x"].median()
stud["cgpa_x"] = stud["cgpa_x"].replace(0, median_value)
median_value = stud["cgpa_y"].median()
stud["cgpa_y"] = stud["cgpa_y"].replace(0, median_value)
stud
# Out:
#     regnum      name  attendance  theorymarks  city_x  studyhours_x  cgpa_x  \
# 0      100      ravi          80           85     blr             3       4
# 1      101      manu          50           60     chn             3       9
# 2      102      raja          32           50     hyd             8       7
# 3      103      manu          85           80     mum             3       6
# 4      104      arun          86           70     del             1       7
# 5      105    mahesh          53           48   noida             4       8
# 6      106    rajesh          19           69    pune             7       4
# 7      107    mahesh          14           68     blr             4       8
# 8      108    rakesh          18           78   noida             3       6
# 9      109     manju          88           57  jaipur             4       8
# 10     110      raju          80           80     blr             4       5
# ...

# %%
stud.describe()
# Out:
#            regnum  attendance  theorymarks  studyhours_x      cgpa_x  \
# count   53.000000   53.000000    53.000000     53.000000   53.000000
# mean   126.000000   60.245283    64.641509     32.415094   21.716981
# std     15.443445   27.591042    14.432994    205.476036  108.974834
# min    100.000000   11.000000    40.000000      1.000000    4.000000
# 25%    113.000000   40.000000    51.000000      3.000000    5.000000
# 50%    126.000000   58.000000    65.000000      4.000000    7.000000
# 75%    139.000000   85.000000    80.000000      6.000000    8.000000
# max    152.000000  100.000000    85.000000   1500.000000  800.000000
#
#        studyhours_y      cgpa_y
# count     53.000000   53.000000
# mean      32.415094   21.716981
# std      205.476036  108.974834
# min        1.000000    4.000000
# 25%        3.000000    5.000000
# 50%        4.000000    7.000000
# 75%        6.000000    8.000000
# max     1500.000000  800.000000

# %%
num = ['studyhours_x']

num.sort()
q1, q3= np.percentile(numlst,[25,75])
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[92], line 4
#       1 num = ['studyhours_x']
#       3 num.sort()
# ----> 4 q1, q3= np.percentile(numlst,[25,75])
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\function_base.py:4283, in percentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4281 if not _quantile_is_valid(q):
#    4282     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 4283 return _quantile_unchecked(
#    4284     a, q, axis, out, overwrite_input, method, keepdims)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\function_base.py:4555, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4547 def _quantile_unchecked(a,
#    4548                         q,
#    4549                         axis=None,
#    (...)
#    4552                         method="linear",
# ...
